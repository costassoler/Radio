# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
import ugradio

# %% [markdown]
# ## Data Collection

# %%
x1 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.1',x1)

# %%
np.loadtxt('trial0.1')
# Out:
# array([-15360., -13824.,  -6912., ...,   2304.,  -7168., -13824.])

# %%
x2 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.2',x2)

# %%
np.loadtxt('trial0.2')
# Out:
# array([  7680.,  -8448., -12800., ...,  -7424.,   8704.,  13056.])

# %%
x3 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.3',x3)

# %%
np.loadtxt('trial0.3')
# Out:
# array([ 11264.,  -6656.,  -6912., ..., -11008.,      0.,  11264.])

# %%
x4 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.4',x4)

# %%
np.loadtxt('trial0.4')
# Out:
# array([-8960.,  9472., -6144., ..., -6400.,  1024.,  4864.])

# %%
x5 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.5',x5)

# %%
np.loadtxt('trial0.5')
# Out:
# array([ 2048., -1792.,  2048., ..., -7424.,  7424., -7424.])

# %%
x6 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.6',x6)

# %%
np.loadtxt('trial0.6')
# Out:
# array([ 5888., -4096.,   768., ..., -5632.,  3840.,  -256.])

# %%
x7 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.7',x7)

# %%
np.loadtxt('trial0.7')
# Out:
# array([-2304., -1536.,  3584., ...,  2560., -2816.,  -768.])

# %%
x8 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.8',x8)

# %%
np.loadtxt('trial0.8')
# Out:
# array([ -512.,   768.,  1024., ...,  1024.,     0., -1024.])

# %%
x9 = ugradio.pico.capture_data('1V',nsamples=2000)

# %%
np.savetxt('trial0.9',x9)

# %%
np.loadtxt('trial0.9')
# Out:
# array([-12800.,  -2560.,   8704., ...,  12544.,  18432.,  17152.])

# %% [markdown]
# ## Calculations

# %%
# Total time for collection 
timetot = 2000/(31.25e6)
timetot
# Out:
# 6.4e-05

# %%
time = np.linspace(0, timetot, 2000)

# %%
len(time)
# Out:
# 2000

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.1')[1:30]*10**6, 'k.-')
plt.title('Trial 1: 3.125MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.2')[1:30]*10**6, 'k.-')
plt.title('Trial 2: 6.25MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.3')[1:30]*10**6, 'k.-')
plt.title('Trial 3: 9.375MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.4')[1:30]*10**6, 'k.-')
plt.title('Trial 4: 12.5MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.5')[1:30]*10**6, 'k.-')
plt.title('Trial 5: 15.625MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.6')[1:30]*10**6, 'k.-')
plt.title('Trial 6: 18.75MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.7')[1:30]*10**6, 'k.-')
plt.title('Trial 7: 21.875MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.8')[1:30]*10**6, 'k.-')
plt.title('Trial 8: 25.0MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()

# %%
plt.plot(time[1:30]*10**6, np.loadtxt('trial0.9')[1:30]*10**6, 'k.-')
plt.title('Trial 9: 28.125MHz')
plt.ylabel('Frequency (MHz)')
plt.xlabel('Time (microsec)')
plt.show()
