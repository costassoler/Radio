# %%
import numpy as np
import spectra

# %%
#up = np.loadtxt('uppertestsig')
#low = np.loadtxt('lowertestsig')

# %%
#%matplotlib notebook
#spectra.plot_power(up, 100, 'up')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3d8eecea1eb1> in <module>()
#       1 get_ipython().magic(u'matplotlib notebook')
# ----> 2 spectra.plot_power(up, 100, 'up')
#
# NameError: name 'up' is not defined

# %%
#spectra.plot_power(low, 100, 'low')

# %%
w = np.loadtxt('oneMHz')

# %%
spectra.plot_power(w,100,'weehaw')
# Out:
# <img src="data:image/png;base64,...">

# %%
buh  = np.loadtxt('negOneMHz')

# %%
spectra.plot_power(buh,100,'weehaw')
